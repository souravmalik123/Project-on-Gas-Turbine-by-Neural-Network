# %% [markdown]
# Import The Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("gas_turbines.csv")

# %%
df.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df.shape
# Out:
# (15039, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
df.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %% [markdown]
# Spliting the Data set into Features And Target

# %%
x = df.drop(columns="TEY",axis=-1)
y = df["TEY"]

# %%
x.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
#
#       NOX
# 0  82.722
# 1  82.776
# 2  82.468
# 3  82.670
# 4  82.311

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

std_data = pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
std_data
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             TEY       CDP        CO       NOX
# 0     -1.231172 -1.357331  0.532012  1.387845
# 1     -1.229909 -1.363676  0.568733  1.393002
# 2     -1.230541 -1.360957  0.552938  1.363586
# 3     -1.229909 -1.356424  0.548933  1.382878
# 4     -1.229909 -1.350985  0.574179  1.348591
# ...         ...       ...       ...       ...
# 15034 -1.426381 -1.543161  1.145792  1.085751
# 15035 -1.415642 -1.513247  1.293578  1.119943
# 15036 -1.516089 -1.467922  2.695925  2.170062
# 15037 -1.481343 -1.422598  1.924683  2.391165
# 15038 -1.428277 -1.377273  1.354150  2.321539
#
# [15039 rows x 11 columns]

# %% [markdown]
# Spliting the into x and y

# %%
x = std_data.drop('TEY',axis=1)
y = std_data[['TEY']]

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting data into test data and train data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=3)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (15039, 10) (11279, 10) (3760, 10)

# %%
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From C:\Users\MD SUHAIL MALIK\Documents\Python Scripts\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Build the model
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=x_train.shape[1]))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=1))
# Out:
# WARNING:tensorflow:From C:\Users\MD SUHAIL MALIK\Documents\Python Scripts\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\MD SUHAIL MALIK\Documents\Python Scripts\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\MD SUHAIL MALIK\Documents\Python Scripts\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 353/353 [==============================] - 1s 1ms/step - loss: 0.0802
# Epoch 2/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 3/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 4/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 5/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 6/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 7/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 8/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 9/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 10/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 11/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 12/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 13/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 14/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 15/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 16/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 17/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 18/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 19/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 20/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 21/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 22/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 23/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 24/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 25/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 26/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 27/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 28/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 29/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 30/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 31/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 32/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 33/100
# 353/353 [==============================] - 1s 3ms/step - loss: 0.0012
# Epoch 34/100
# 353/353 [==============================] - 1s 4ms/step - loss: 0.0012
# Epoch 35/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 36/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 37/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 38/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 39/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 40/100
# 353/353 [==============================] - 1s 1ms/step - loss: 0.0012
# Epoch 41/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 42/100
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 43/100
# 353/353 [==============================] - 1s 1ms/step - loss: 0.0011
# Epoch 44/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 45/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 46/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 47/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 48/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 49/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 50/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 51/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 52/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 53/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 54/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 55/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 56/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 57/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 58/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 59/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 60/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 61/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 62/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 63/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 64/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 65/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 66/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 67/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 68/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 69/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 70/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 71/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 72/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9138e-04
# Epoch 73/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 74/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 75/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9711e-04
# Epoch 76/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 77/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9021e-04
# Epoch 78/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 79/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 80/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 81/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 82/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.6642e-04
# Epoch 83/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9284e-04
# Epoch 84/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.7713e-04
# Epoch 85/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9486e-04
# Epoch 86/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 87/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.8974e-04
# Epoch 88/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9624e-04
# Epoch 89/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 90/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9751e-04
# Epoch 91/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.6838e-04
# Epoch 92/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.9867e-04
# Epoch 93/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.7857e-04
# Epoch 94/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.6458e-04
# Epoch 95/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.7403e-04
# Epoch 96/100
# 353/353 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 97/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.6470e-04
# Epoch 98/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.7466e-04
# Epoch 99/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.6335e-04
# Epoch 100/100
# 353/353 [==============================] - 0s 1ms/step - loss: 9.5497e-04

# %%
# Evaluate the model on the test set
test_loss = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", test_loss)
# Out:
# Test loss: 0.0011374158784747124

# %%
 ##  Make predictions on new data
new_data = np.array([[6.8594,1007.9,96.799,3.5000,19.663,1059.2,550.00,10.605,3.1547,82.722]])
new_data = pd.DataFrame(scaler.fit_transform(new_data))
predictions = model.predict(new_data)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 142ms/step
# Predictions: [[-0.01429555]]

# %% [markdown]
# building the model with best parameter found through hyper parameter tunning

# %%
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
def build_model(hidden_layer_neurons, activation, optimizer):
    model1 = Sequential()
    model1.add(Dense(hidden_layer_neurons, input_dim=10, activation=activation))
    model1.add(Dense(hidden_layer_neurons, activation=activation))
    model1.add(Dense(1))
    model1.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# Use the hyperparameters found through hyperparameter tuning
best_hidden_layer_neurons = 256
best_activation = 'relu'
best_optimizer = Adam()

model1 = build_model(best_hidden_layer_neurons, best_activation, best_optimizer)
model1.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.5979e-04 - val_loss: 0.0012
# Epoch 2/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4075e-04 - val_loss: 0.0011
# Epoch 3/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4866e-04 - val_loss: 0.0011
# Epoch 4/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4100e-04 - val_loss: 0.0012
# Epoch 5/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.6896e-04 - val_loss: 0.0013
# Epoch 6/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.6406e-04 - val_loss: 0.0012
# Epoch 7/50
# 353/353 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 8/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.6424e-04 - val_loss: 0.0014
# Epoch 9/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.5016e-04 - val_loss: 0.0011
# Epoch 10/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4710e-04 - val_loss: 0.0011
# Epoch 11/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2987e-04 - val_loss: 0.0013
# Epoch 12/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.6701e-04 - val_loss: 0.0011
# Epoch 13/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4361e-04 - val_loss: 0.0011
# Epoch 14/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.5497e-04 - val_loss: 0.0013
# Epoch 15/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.3452e-04 - val_loss: 0.0011
# Epoch 16/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.6180e-04 - val_loss: 0.0012
# Epoch 17/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1515e-04 - val_loss: 0.0011
# Epoch 18/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4892e-04 - val_loss: 0.0011
# Epoch 19/50
# 353/353 [==============================] - 1s 4ms/step - loss: 9.4551e-04 - val_loss: 0.0013
# Epoch 20/50
# 353/353 [==============================] - 1s 4ms/step - loss: 9.3144e-04 - val_loss: 0.0011
# Epoch 21/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.3935e-04 - val_loss: 0.0011
# Epoch 22/50
# 353/353 [==============================] - 1s 4ms/step - loss: 9.1947e-04 - val_loss: 0.0012
# Epoch 23/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.5451e-04 - val_loss: 0.0011
# Epoch 24/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4070e-04 - val_loss: 0.0011
# Epoch 25/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2356e-04 - val_loss: 0.0011
# Epoch 26/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.5323e-04 - val_loss: 0.0012
# Epoch 27/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.0312e-04 - val_loss: 0.0011
# Epoch 28/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4247e-04 - val_loss: 0.0013
# Epoch 29/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2677e-04 - val_loss: 0.0011
# Epoch 30/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.7185e-04 - val_loss: 0.0011
# Epoch 31/50
# 353/353 [==============================] - 1s 1ms/step - loss: 9.2883e-04 - val_loss: 0.0011
# Epoch 32/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.3164e-04 - val_loss: 0.0011
# Epoch 33/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1230e-04 - val_loss: 0.0013
# Epoch 34/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.0785e-04 - val_loss: 0.0011
# Epoch 35/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1156e-04 - val_loss: 0.0011
# Epoch 36/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1477e-04 - val_loss: 0.0011
# Epoch 37/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1584e-04 - val_loss: 0.0011
# Epoch 38/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2781e-04 - val_loss: 0.0011
# Epoch 39/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1367e-04 - val_loss: 0.0012
# Epoch 40/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2603e-04 - val_loss: 0.0011
# Epoch 41/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.4496e-04 - val_loss: 0.0012
# Epoch 42/50
# 353/353 [==============================] - 1s 2ms/step - loss: 8.9267e-04 - val_loss: 0.0013
# Epoch 43/50
# 353/353 [==============================] - 1s 2ms/step - loss: 8.9997e-04 - val_loss: 0.0013
# Epoch 44/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.0901e-04 - val_loss: 0.0014
# Epoch 45/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.0683e-04 - val_loss: 0.0011
# Epoch 46/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.1834e-04 - val_loss: 0.0012
# Epoch 47/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2646e-04 - val_loss: 0.0012
# Epoch 48/50
# 353/353 [==============================] - 1s 2ms/step - loss: 8.9017e-04 - val_loss: 0.0011
# Epoch 49/50
# 353/353 [==============================] - 1s 2ms/step - loss: 9.2141e-04 - val_loss: 0.0013
# Epoch 50/50
# 353/353 [==============================] - 1s 2ms/step - loss: 8.9166e-04 - val_loss: 0.0011

# %%
# Evaluate the model on the test set
test_loss = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", test_loss)
# Out:
# Test loss: 0.0011150852078571916

# %% [markdown]
# Finding predicted values for test data

# %%
# generating predictions for test data
y_predict_test = model1.predict(x_test) 

# creating table with test price & predicted price for test
predictions_df = pd.DataFrame(x_test)
predictions_df['Actual'] = y_test
predictions_df['Predicted'] = y_predict_test
print(predictions_df.shape)
predictions_df.head(10)
# Out:
# 118/118 [==============================] - 0s 986us/step
# (3760, 12)
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 8185  -1.295034  0.483697  0.728184  1.062795  1.821837  0.974223 -2.239381
# 8994  -1.586410  0.811282 -0.098251 -0.212050 -0.486864 -0.042280  0.587783
# 8944  -1.200871  2.121622  0.379601  1.633192  1.789731  0.992375 -2.358874
# 3451   0.238527  0.312104  0.873910 -1.169860 -1.403779 -1.669894  0.567443
# 8236  -1.477354  0.530495  0.720934 -0.567233 -0.451644  0.042429  0.573799
# 3508   1.771520 -0.514658 -2.837035  0.277577  0.343799  0.786654  0.600495
# 6768  -0.290383  1.154466 -0.643093 -1.760516 -0.211574  0.242099  0.590325
# 11903  1.556972 -1.154229 -0.918668  0.300993  1.098750  0.998425 -0.535964
# 9257  -1.143755  2.277615  0.384168  1.862746  1.741573  0.998425 -2.376671
# 2911   1.350742  0.062516 -1.840949 -0.009464  0.130083  0.568832  0.575071
#
#             CDP        CO       NOX    Actual  Predicted
# 8185   1.807215 -0.691358 -0.357197  1.904806   1.853954
# 8994  -0.319403 -0.007020 -0.746013 -0.032754  -0.061036
# 8944   1.918713 -0.694018 -0.444778  1.846054   1.840199
# 3451  -1.634716  1.525787 -1.103885 -1.541991  -1.538616
# 8236  -0.260482 -0.153231  1.083363  0.051900   0.015725
# 3508   0.256216 -0.364829  0.623392  0.065798   0.038491
# 6768  -0.062867 -0.505505 -0.502370  0.021576  -0.008792
# 11903  0.951492 -0.661310 -1.381051  0.767666   0.794739
# 9257   1.896958 -0.383325 -0.702557  1.832787   1.829534
# 2911   0.075825 -0.243999  0.125314 -0.022646  -0.021188

# %% [markdown]
# Plotting Actual values verses Prediced values

# %%
plt.figure(figsize=(12,8))
plt.xlabel("Actual Values")
plt.ylabel("Predicted values")
plt.title("The Scatterplot of Relationship between Actual Values and Predictions")
plt.scatter(predictions_df['Actual'], predictions_df['Predicted'])
